# %%
import cv2
import numpy as np

im = cv2.imread(r"images\cat_in_grass.jpg")

# %%
im_height, im_width = im.shape[:2]

# stripe_width = int(input())
stripe_width = 100
print(im_height)
# Out:
# 552

# %%
print(int(im_height /stripe_width))
# Out:
# 5

# %%
for stripes = 

im_height, im_width = im.shape[:2]

roi_copy = im[0 : int(im_height / 10), 0:im_width].copy()

# im_resized = cv2.resize(im, (300, 300))
# im[int(im_height / 10) : (int(im_height / 10) * 2), 0:im_width] = roi_copy

cv2.imshow("Original Image", im)
cv2.imshow("ROI Image", roi_copy)
cv2.waitKey(0)
